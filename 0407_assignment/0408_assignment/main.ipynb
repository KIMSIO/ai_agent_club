# %%
import openai

client = openai.OpenAI()
messages = []

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
    )
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})
    print(f"AI: {message}")

# %%
while True:
    message = input("Send a message to the LLM...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User: {message}")
        call_ai()
# Out:
# User: 나는 애니메이션 영화를 좋아해
# AI: 애니메이션 영화는 정말 매력적이죠! 다양한 스타일과 이야기로 많은 사람들에게 감동을 주고 즐거움을 선사합니다. 어떤 애니메이션 영화를 가장 좋아하시나요? 또는 추천받고 싶은 영화가 있으신가요?
# User: 소울, 코코 재밌게 봤어.
# AI: "소울"과 "코코" 모두 훌륭한 애니메이션 영화입니다!
#
# "소울"은 삶의 의미와 꿈을 찾아가는 여정을 다루고 있어서 감동적이고 깊은 메시지를 주죠. 음악의 힘과 함께 더욱 풍부해진 이야기로 많은 사랑을 받았습니다.
#
# "코코"는 가족과 전통, 기억의 소중함을 다룬 작품으로, 아름다운 비주얼과 감정적인 스토리로 관객들을 매료시켰습니다. 특히 멕시코 문화의 요소들이 잘 녹아 있어 기억에 남는 영화입니다.
#
# 이 외에도 이런 감동적인 이야기를 원하신다면 "겨울왕국"이나 "주토피아", "미래의 미라이" 같은 영화들도 추천드려요! 어떤 영화가 궁금하신가요?
# User: 오늘 밤에 뭐볼지 추천해줄래? 이미 본 건 제외하고, 네가 분석한 내 취향에 기반해서
# AI: 물론이에요! "소울"과 "코코"를 좋아하셨다면, 감정적으로 깊고 시각적으로 아름다운 애니메이션이 어울릴 것 같아요. 다음 영화들을 추천해드릴게요:
#
# 1. **쓰리 빌보드**: 이 애니메이션은 아니지만, 깊은 스토리와 감정이 잘 담긴 작품입니다. 강렬한 캐릭터들에 대해 높은 평가를 받고 있습니다.
#
# 2. **온워드: 단 하루의 이야기**: 가족과 모험을 주제로 한 애니메이션으로, 형제 간의 우애를 다루고 있어 "코코"의 감정적인 요소와 잘 어울립니다.
#
# 3. **어 라이프**: 소중한 순간들을 기억하고 일상을 살아가는 이야기를 담고 있어, "소울"과 유사한 감성을 느낄 수 있습니다.
#
# 4. **주토피아**: 다양한 캐릭터들 간의 유대와 사회적 메시지가 담긴 영화로, 재치 있는 유머와 감동적인 순간을 제공합니다.
#
# 이외에도 좋아할 만한 애니메이션들이 많지만, 이 네 가지는 확실히 당신의 취향에 맞을 것 같아요. 즐거운 감상 되시길 바랍니다!
